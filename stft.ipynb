# %% [markdown]
# <a href="https://colab.research.google.com/github/artisticdrake/Srishti23/blob/main/stft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import librosa
import numpy as np
c,d=0,0
# Define the path to the folder containing the audio samples
audio_folder = "/content/drive/MyDrive/sptaud/m"
nl=[]
avg=[]
# Define the classification threshold
classification_threshold = 500

# Iterate through each audio file in the folder
for filename in os.listdir(audio_folder):
    audio_path = os.path.join(audio_folder, filename)
    

    # Load the audio file
    audio, sr = librosa.load(audio_path, sr=None)

    # Apply STFT
    stft = np.abs(librosa.stft(audio))

    # Compute the spectral centroid feature
    spectral_centroid = librosa.feature.spectral_centroid(S=stft)

    # Calculate the average spectral centroid across time
    avg_spectral_centroid = np.mean(spectral_centroid)
    #print(avg_spectral_centroid)
    avg.append(avg_spectral_centroid)

    # Classify as speech or noise based on the spectral centroid
    if avg_spectral_centroid > classification_threshold:
        #print("Processing:", filename)
        #print("Classification: Speech")
        nl.append(filename)
        c+=1

    else:
        d+=1
        print("Processing:", filename)
        print("Classification: Noise")
        pass
# Out:
# Processing: m1.mp3
# Classification: Noise
# Processing: m2.mp3
# Classification: Noise
# Processing: m3.mp3
# Classification: Noise
# Processing: m4.mp3
# Classification: Noise
# Processing: m5.mp3
# Classification: Noise
# Processing: m6.mp3
# Classification: Noise
# Processing: m7.mp3
# Classification: Noise
# Processing: m8.mp3
# Classification: Noise
# Processing: m9.mp3
# Classification: Noise
# Processing: m10.mp3
# Classification: Noise
# Processing: m13.mp3
# Classification: Noise
# Processing: m14.mp3
# Classification: Noise
# Processing: m15.mp3
# Classification: Noise
# Processing: m16.mp3
# Classification: Noise
# Processing: m17.mp3
# Classification: Noise
# Processing: m18.mp3
# Classification: Noise
# Processing: m19.mp3
# Classification: Noise
# Processing: m20.mp3
# Classification: Noise
# Processing: m21.mp3
# Classification: Noise
# Processing: m22.mp3
# Classification: Noise
# Processing: m23.mp3
# Classification: Noise
# Processing: m24.mp3
# Classification: Noise
# Processing: m25.mp3
# Classification: Noise
# Processing: m26.mp3
# Classification: Noise
# Processing: m27.mp3
# Classification: Noise
# Processing: m28.mp3
# Classification: Noise
# Processing: m29.mp3
# Classification: Noise
# Processing: m30.mp3
# Classification: Noise
# Processing: m31.mp3
# Classification: Noise
# Processing: m32.mp3
# Classification: Noise
# Processing: m33.mp3
# Classification: Noise
# Processing: m42.mp3
# Classification: Noise
# Processing: m44.mp3
# Classification: Noise
# Processing: m45.mp3
# Classification: Noise
# Processing: m47.mp3
# Classification: Noise
# Processing: m50.mp3
# Classification: Noise
# Processing: m51.mp3
# Classification: Noise
# Processing: m52.mp3
# Classification: Noise
# Processing: m53.mp3
# Classification: Noise
# Processing: m56.mp3
# Classification: Noise
# Processing: m57.mp3
# Classification: Noise
# Processing: m59.mp3
# Classification: Noise
# Processing: m62.mp3
# Classification: Noise
# Processing: m67.mp3
# Classification: Noise
# Processing: m86.mp3
# Classification: Noise
# Processing: m88.mp3
# Classification: Noise
# Processing: m96.mp3
# Classification: Noise
# Processing: m104.mp3
# Classification: Noise
# Processing: m106.mp3
# Classification: Noise
# Processing: m112.mp3
# Classification: Noise
# Processing: m113.mp3
# Classification: Noise
# Processing: m134.mp3
# Classification: Noise
# Processing: m136.mp3
# Classification: Noise
# Processing: m140.mp3
# Classification: Noise
# Processing: m143.mp3
# Classification: Noise
# Processing: m154.mp3
# Classification: Noise
# Processing: m166.mp3
# Classification: Noise
# Processing: m169.mp3
# Classification: Noise
# Processing: m170.mp3
# Classification: Noise
# Processing: m171.mp3
# Classification: Noise
# Processing: m172.mp3
# Classification: Noise
# Processing: m173.mp3
# Classification: Noise
# Processing: m176.mp3
# Classification: Noise
# Processing: m178.mp3
# Classification: Noise
# Processing: m182.mp3
# Classification: Noise
# Processing: m188.mp3
# Classification: Noise
# Processing: m191.mp3
# Classification: Noise
# Processing: m192.mp3
# Classification: Noise
# Processing: m193.mp3
# Classification: Noise
# Processing: m197.mp3
# Classification: Noise
# Processing: m198.mp3
# Classification: Noise
# Processing: m200.mp3
# Classification: Noise
# Processing: m203.mp3
# Classification: Noise
# Processing: m205.mp3
# Classification: Noise
# Processing: m207.mp3
# Classification: Noise
# Processing: m208.mp3
# Classification: Noise
# Processing: m210.mp3
# Classification: Noise
# Processing: m211.mp3
# Classification: Noise
# Processing: m212.mp3
# Classification: Noise
# Processing: m213.mp3
# Classification: Noise
# Processing: m214.mp3
# Classification: Noise
# Processing: m215.mp3
# Classification: Noise
# Processing: m216.mp3
# Classification: Noise
# Processing: m218.mp3
# Classification: Noise
# Processing: m219.mp3
# Classification: Noise
# Processing: m220.mp3
# Classification: Noise
# Processing: m221.mp3
# Classification: Noise
# Processing: m222.mp3
# Classification: Noise
# Processing: m223.mp3
# Classification: Noise
# Processing: m224.mp3
# Classification: Noise
# Processing: m225.mp3
# Classification: Noise
# Processing: m226.mp3
# Classification: Noise
# Processing: m227.mp3
# Classification: Noise
# Processing: m229.mp3
# Classification: Noise
# Processing: m230.mp3
# Classification: Noise
# Processing: m231.mp3
# Classification: Noise
# Processing: m232.mp3
# Classification: Noise
# Processing: m233.mp3
# Classification: Noise
# Processing: m234.mp3
# Classification: Noise
# Processing: m236.mp3
# Classification: Noise
# Processing: m238.mp3
# Classification: Noise
# Processing: m239.mp3
# Classification: Noise
# Processing: m240.mp3
# Classification: Noise
# Processing: m241.mp3
# Classification: Noise
# Processing: m242.mp3
# Classification: Noise
# Processing: m243.mp3
# Classification: Noise
# Processing: m244.mp3
# Classification: Noise
# Processing: m245.mp3
# Classification: Noise
# Processing: m247.mp3
# Classification: Noise
# Processing: m248.mp3
# Classification: Noise
# Processing: m249.mp3
# Classification: Noise
# Processing: m250.mp3
# Classification: Noise
# Processing: m251.mp3
# Classification: Noise
# Processing: m252.mp3
# Classification: Noise
# Processing: m264.mp3
# Classification: Noise
# Processing: m265.mp3
# Classification: Noise
# Processing: m268.mp3
# Classification: Noise
# Processing: m269.mp3
# Classification: Noise
# Processing: m270.mp3
# Classification: Noise
# Processing: m271.mp3
# Classification: Noise
# Processing: m272.mp3
# Classification: Noise
# Processing: m273.mp3
# Classification: Noise
# Processing: m274.mp3
# Classification: Noise
# Processing: m275.mp3
# Classification: Noise
# Processing: m306.mp3
# Classification: Noise
# Processing: m311.mp3
# Classification: Noise
# Processing: m321.mp3
# Classification: Noise
# Processing: m322.mp3
# Classification: Noise
# Processing: m324.mp3
# Classification: Noise
# Processing: m325.mp3
# Classification: Noise
# Processing: m326.mp3
# Classification: Noise
# Processing: m327.mp3
# Classification: Noise
# Processing: m328.mp3
# Classification: Noise
# Processing: m329.mp3
# Classification: Noise
# Processing: m330.mp3
# Classification: Noise
# Processing: m331.mp3
# Classification: Noise
# Processing: m332.mp3
# Classification: Noise
# Processing: m333.mp3
# Classification: Noise
# Processing: m334.mp3
# Classification: Noise
# Processing: m335.mp3
# Classification: Noise
# Processing: m336.mp3
# Classification: Noise
# Processing: m337.mp3
# Classification: Noise
# Processing: m338.mp3
# Classification: Noise
# Processing: m340.mp3
# Classification: Noise
# Processing: m341.mp3
# Classification: Noise
# Processing: m342.mp3
# Classification: Noise
# Processing: m343.mp3
# Classification: Noise
# Processing: m344.mp3
# Classification: Noise
# Processing: m347.mp3
# Classification: Noise
# Processing: m349.mp3
# Classification: Noise
# Processing: m350.mp3
# Classification: Noise
# Processing: m351.mp3
# Classification: Noise
# Processing: m353.mp3
# Classification: Noise
# Processing: m354.mp3
# Classification: Noise
# Processing: m355.mp3
# Classification: Noise
# Processing: m356.mp3
# Classification: Noise
# Processing: m357.mp3
# Classification: Noise
# Processing: m358.mp3
# Classification: Noise
# Processing: m359.mp3
# Classification: Noise
# Processing: m360.mp3
# Classification: Noise
# Processing: m361.mp3
# Classification: Noise
# Processing: m362.mp3
# Classification: Noise
# Processing: m363.mp3
# Classification: Noise
# Processing: m364.mp3
# Classification: Noise
# Processing: m369.mp3
# Classification: Noise
# Processing: m368.mp3
# Classification: Noise
# Processing: m371.mp3
# Classification: Noise
# Processing: m370.mp3
# Classification: Noise
# Processing: m372.mp3
# Classification: Noise
# Processing: m374.mp3
# Classification: Noise
# Processing: m373.mp3
# Classification: Noise
# Processing: m375.mp3
# Classification: Noise
# Processing: m377.mp3
# Classification: Noise
# Processing: m376.mp3
# Classification: Noise
# Processing: m379.mp3
# Classification: Noise
# Processing: m378.mp3
# Classification: Noise
# Processing: m380.mp3
# Classification: Noise
# Processing: m389.mp3
# Classification: Noise
# Processing: m391.mp3
# Classification: Noise
# Processing: m390.mp3
# Classification: Noise
# Processing: m394.mp3
# Classification: Noise
# Processing: m393.mp3
# Classification: Noise
# Processing: m395.mp3
# Classification: Noise
# Processing: m400.mp3
# Classification: Noise
# Processing: m402.mp3
# Classification: Noise
# Processing: m404.mp3
# Classification: Noise
# Processing: m405.mp3
# Classification: Noise
# Processing: m410.mp3
# Classification: Noise

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
avg=np.array(avg)

# %%
c,d
# Out:
# (343, 59)

# %%
import matplotlib as plt
import seaborn as sns

sns.histplot(avg, kde=True,color='blue',label="Only Voice")
# Out:
# <Axes: ylabel='Count'>
